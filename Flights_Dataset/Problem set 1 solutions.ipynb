# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from pandas import *

# %%
flights = pd.read_csv('flights.csv')

# %%
print flights_df.head();
print flights_df.tail();
print flights_df.describe();

# %%
print flights.shape
# Out:
# (336776, 17)

# %%
print flights.columns
# Out:
# Index([u'Unnamed: 0', u'year', u'month', u'day', u'dep_time', u'dep_delay',
#        u'arr_time', u'arr_delay', u'carrier', u'tailnum', u'flight', u'origin',
#        u'dest', u'air_time', u'distance', u'hour', u'minute'],
#       dtype='object')

# %%
print flights.dtypes
# Out:
# Unnamed: 0      int64
# year            int64
# month           int64
# day             int64
# dep_time      float64
# dep_delay     float64
# arr_time      float64
# arr_delay     float64
# carrier        object
# tailnum        object
# flight          int64
# origin         object
# dest           object
# air_time      float64
# distance        int64
# hour          float64
# minute        float64
# dtype: object

# %%
flights.dest.unique()
# Out:
# array(['IAH', 'MIA', 'BQN', 'ATL', 'ORD', 'FLL', 'IAD', 'MCO', 'PBI',
#        'TPA', 'LAX', 'SFO', 'DFW', 'BOS', 'LAS', 'MSP', 'DTW', 'RSW',
#        'SJU', 'PHX', 'BWI', 'CLT', 'BUF', 'DEN', 'SNA', 'MSY', 'SLC',
#        'XNA', 'MKE', 'SEA', 'ROC', 'SYR', 'SRQ', 'RDU', 'CMH', 'JAX',
#        'CHS', 'MEM', 'PIT', 'SAN', 'DCA', 'CLE', 'STL', 'MYR', 'JAC',
#        'MDW', 'HNL', 'BNA', 'AUS', 'BTV', 'PHL', 'STT', 'EGE', 'AVL',
#        'PWM', 'IND', 'SAV', 'CAK', 'HOU', 'LGB', 'DAY', 'ALB', 'BDL',
#        'MHT', 'MSN', 'GSO', 'CVG', 'BUR', 'RIC', 'GSP', 'GRR', 'MCI',
#        'ORF', 'SAT', 'SDF', 'PDX', 'SJC', 'OMA', 'CRW', 'OAK', 'SMF',
#        'TUL', 'TYS', 'OKC', 'PVD', 'DSM', 'PSE', 'BHM', 'CAE', 'HDN',
#        'BZN', 'MTJ', 'EYW', 'PSP', 'ACK', 'BGR', 'ABQ', 'ILM', 'MVY',
#        'SBN', 'LEX', 'CHO', 'TVC', 'ANC', 'LGA'], dtype=object)

# %%
flights.head(10)

# %% [markdown]
# # Create a new dataframe df_1 with flights form NYC to SEA

# %%
flights[(flights.origin=='JFK') & (flights.dest=='SEA')]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5ad889a9dc51> in <module>()
# ----> 1 flights[(flights.origin=='JFK') & (flights.dest=='SEA')]
#
# NameError: name 'flights' is not defined

# %%
flights[(flights.month >= 3) & (flights.month <= 6)]
# Out:
#         Unnamed: 0  year  month  day  dep_time  dep_delay  arr_time  \
# 136247      136248  2013      3    1       4.0      125.0     318.0
# 136248      136249  2013      3    1      50.0       52.0     526.0
# 136249      136250  2013      3    1     117.0      152.0     223.0
# 136250      136251  2013      3    1     454.0       -6.0     633.0
# 136251      136252  2013      3    1     505.0      -10.0     746.0
# 136252      136253  2013      3    1     521.0       -9.0     813.0
# 136253      136254  2013      3    1     537.0       -3.0     856.0
# 136254      136255  2013      3    1     541.0       -4.0    1014.0
# 136255      136256  2013      3    1     549.0      -11.0     639.0
# 136256      136257  2013      3    1     550.0      -10.0     747.0
# 136257      136258  2013      3    1     551.0       -8.0     722.0
# 136258      136259  2013      3    1     551.0       -9.0     717.0
# 136259      136260  2013      3    1     551.0       -9.0     845.0
# 136260      136261  2013      3    1     552.0       -8.0     656.0
# 136261      136262  2013      3    1     554.0       -6.0     651.0
# 136262      136263  2013      3    1     555.0       -5.0     715.0
# 136263      136264  2013      3    1     556.0       -4.0     901.0
# 136264      136265  2013      3    1     557.0       -3.0     837.0
# 136265      136266  2013      3    1     557.0       -3.0     706.0
# 136266      136267  2013      3    1     558.0       -2.0     750.0
# 136267      136268  2013      3    1     558.0       -2.0     903.0
# 136268      136269  2013      3    1     558.0       -7.0     803.0
# 136269      136270  2013      3    1     559.0       -1.0     713.0
# 136270      136271  2013      3    1     559.0       -1.0     831.0
# 136271      136272  2013      3    1     600.0       -5.0     804.0
# 136272      136273  2013      3    1     600.0        0.0     848.0
# 136273      136274  2013      3    1     600.0        0.0     911.0
# 136274      136275  2013      3    1     600.0        0.0     906.0
# 136275      136276  2013      3    1     601.0       -4.0     758.0
# 136276      136277  2013      3    1     601.0        1.0     827.0
# ...            ...   ...    ...  ...       ...        ...       ...
# 250420      250421  2013      6   30       NaN        NaN       NaN
# 250421      250422  2013      6   30       NaN        NaN       NaN
# 250422      250423  2013      6   30       NaN        NaN       NaN
# 250423      250424  2013      6   30       NaN        NaN       NaN
# 250424      250425  2013      6   30       NaN        NaN       NaN
# 250425      250426  2013      6   30       NaN        NaN       NaN
# 250426      250427  2013      6   30       NaN        NaN       NaN
# 250427      250428  2013      6   30       NaN        NaN       NaN
# 250428      250429  2013      6   30       NaN        NaN       NaN
# 250429      250430  2013      6   30       NaN        NaN       NaN
# 250430      250431  2013      6   30       NaN        NaN       NaN
# 250431      250432  2013      6   30       NaN        NaN       NaN
# 250432      250433  2013      6   30       NaN        NaN       NaN
# 250433      250434  2013      6   30       NaN        NaN       NaN
# 250434      250435  2013      6   30       NaN        NaN       NaN
# 250435      250436  2013      6   30       NaN        NaN       NaN
# 250436      250437  2013      6   30       NaN        NaN       NaN
# 250437      250438  2013      6   30       NaN        NaN       NaN
# 250438      250439  2013      6   30       NaN        NaN       NaN
# 250439      250440  2013      6   30       NaN        NaN       NaN
# 250440      250441  2013      6   30       NaN        NaN       NaN
# 250441      250442  2013      6   30       NaN        NaN       NaN
# 250442      250443  2013      6   30       NaN        NaN       NaN
# 250443      250444  2013      6   30       NaN        NaN       NaN
# 250444      250445  2013      6   30       NaN        NaN       NaN
# 250445      250446  2013      6   30       NaN        NaN       NaN
# 250446      250447  2013      6   30       NaN        NaN       NaN
# 250447      250448  2013      6   30       NaN        NaN       NaN
# 250448      250449  2013      6   30       NaN        NaN       NaN
# 250449      250450  2013      6   30       NaN        NaN       NaN
#
#         arr_delay carrier tailnum  flight origin dest  air_time  distance  \
# 136247      142.0      B6  N706JB      11    JFK  FLL     166.0      1069
# 136248       48.0      B6  N794JB     707    JFK  SJU     198.0      1598
# 136249      149.0      B6  N328JB     608    JFK  PWM      48.0       273
# 136250      -15.0      US  N177US    1117    EWR  CLT      79.0       529
# 136251      -24.0      UA  N527UA     475    EWR  IAH     199.0      1400
# 136252      -14.0      UA  N76523    1714    LGA  IAH     213.0      1416
# 136253        6.0      AA  N5EPAA    1141    JFK  MIA     173.0      1089
# 136254       -9.0      B6  N653JB     725    JFK  BQN     191.0      1576
# 136255      -24.0      US  N749US    2114    LGA  BOS      31.0       184
# 136256      -14.0      EV  N760EV    4911    EWR  DTW      89.0       488
# 136257       -1.0      EV  N26549    4608    EWR  MKE     119.0       725
# 136258      -28.0      AA  N3DCAA     301    LGA  ORD     113.0       733
# 136259      -16.0      B6  N566JB     371    LGA  FLL     155.0      1076
# 136260      -39.0      MQ  N520MQ    3768    EWR  ORD     108.0       719
# 136261       -8.0      US  N755US    2161    LGA  DCA      42.0       214
# 136262        0.0      EV  N828AS    5716    JFK  IAD      52.0       228
# 136263       12.0      B6  N715JB      79    JFK  MCO     157.0       944
# 136264      -33.0      AA  N3AMAA     707    LGA  DFW     196.0      1389
# 136265      -27.0      UA  N834UA     379    LGA  ORD     113.0       733
# 136266       -9.0      DL  N316US     731    LGA  DTW      90.0       502
# 136267        7.0      B6  N589JB     507    EWR  FLL     159.0      1065
# 136268       -2.0      MQ  N713MQ    4401    LGA  DTW      90.0       502
# 136269        5.0      B6  N273JB     380    EWR  BOS      37.0       200
# 136270        6.0      MQ  N513MQ    4650    LGA  ATL     122.0       762
# 136271      -17.0      9E  N8412F    3953    EWR  CVG      87.0       569
# 136272       11.0      DL  N666DN     461    LGA  ATL     117.0       762
# 136273        0.0      UA  N14214    1077    EWR  MIA     168.0      1085
# 136274      -19.0      UA  N505UA     303    JFK  SFO     342.0      2586
# 136275      -19.0      EV  N14570    4603    EWR  CVG      88.0       569
# 136276       12.0      FL  N894AT     345    LGA  ATL     116.0       762
# ...           ...     ...     ...     ...    ...  ...       ...       ...
# 250420        NaN      DL  N317US    2019    LGA  MSP       NaN      1020
# 250421        NaN      DL  N344NB    2042    EWR  ATL       NaN       746
# 250422        NaN      DL  N370NW    2231    LGA  DTW       NaN       502
# 250423        NaN      EV  N11536    4324    EWR  ORF       NaN       284
# 250424        NaN      EV  N24103    4333    EWR  TUL       NaN      1215
# 250425        NaN      EV  N12552    4294    EWR  SAV       NaN       708
# 250426        NaN      EV  N12552    4377    EWR  JAX       NaN       820
# 250427        NaN      EV  N14105    4532    EWR  CHS       NaN       628
# 250428        NaN      EV  N10575    4572    EWR  GSP       NaN       594
# 250429        NaN      EV  N14991    4596    EWR  STL       NaN       872
# 250430        NaN      EV  N13965    4629    EWR  MEM       NaN       946
# 250431        NaN      EV  N12996    4701    EWR  CMH       NaN       463
# 250432        NaN      EV  N13566    4705    EWR  ATL       NaN       746
# 250433        NaN      EV  N605QX    4878    LGA  RDU       NaN       431
# 250434        NaN      EV  N14974    4695    EWR  MHT       NaN       209
# 250435        NaN      EV  N724EV    4969    LGA  MHT       NaN       195
# 250436        NaN      EV  N712EV    4978    LGA  CLT       NaN       544
# 250437        NaN      EV  N712EV    5048    LGA  RIC       NaN       292
# 250438        NaN      EV  N741EV    5207    LGA  BGR       NaN       378
# 250439        NaN      EV  N707EV    5615    EWR  DTW       NaN       488
# 250440        NaN      EV  N716EV    5599    LGA  CHS       NaN       641
# 250441        NaN      EV  N12921    5814    EWR  CLT       NaN       529
# 250442        NaN      EV  N21129    5817    EWR  MEM       NaN       946
# 250443        NaN      EV  N877AS    5712    JFK  IAD       NaN       228
# 250444        NaN      EV  N836AS    5713    LGA  IAD       NaN       229
# 250445        NaN      EV  N836AS    5714    JFK  IAD       NaN       228
# 250446        NaN      EV  N16147    4092    EWR  DAY       NaN       533
# 250447        NaN      EV  N16911    4662    EWR  RDU       NaN       416
# 250448        NaN      EV  N760EV    5254    LGA  DSM       NaN      1031
# 250449        NaN      EV  N744EV    5268    LGA  CLT       NaN       544
#
#         hour  minute
# 136247   0.0     4.0
# 136248   0.0    50.0
# 136249   1.0    17.0
# 136250   4.0    54.0
# 136251   5.0     5.0
# 136252   5.0    21.0
# 136253   5.0    37.0
# 136254   5.0    41.0
# 136255   5.0    49.0
# 136256   5.0    50.0
# 136257   5.0    51.0
# 136258   5.0    51.0
# 136259   5.0    51.0
# 136260   5.0    52.0
# 136261   5.0    54.0
# 136262   5.0    55.0
# 136263   5.0    56.0
# 136264   5.0    57.0
# 136265   5.0    57.0
# 136266   5.0    58.0
# 136267   5.0    58.0
# 136268   5.0    58.0
# 136269   5.0    59.0
# 136270   5.0    59.0
# 136271   6.0     0.0
# 136272   6.0     0.0
# 136273   6.0     0.0
# 136274   6.0     0.0
# 136275   6.0     1.0
# 136276   6.0     1.0
# ...      ...     ...
# 250420   NaN     NaN
# 250421   NaN     NaN
# 250422   NaN     NaN
# 250423   NaN     NaN
# 250424   NaN     NaN
# 250425   NaN     NaN
# 250426   NaN     NaN
# 250427   NaN     NaN
# 250428   NaN     NaN
# 250429   NaN     NaN
# 250430   NaN     NaN
# 250431   NaN     NaN
# 250432   NaN     NaN
# 250433   NaN     NaN
# 250434   NaN     NaN
# 250435   NaN     NaN
# 250436   NaN     NaN
# 250437   NaN     NaN
# 250438   NaN     NaN
# 250439   NaN     NaN
# 250440   NaN     NaN
# 250441   NaN     NaN
# 250442   NaN     NaN
# 250443   NaN     NaN
# 250444   NaN     NaN
# 250445   NaN     NaN
# 250446   NaN     NaN
# 250447   NaN     NaN
# 250448   NaN     NaN
# 250449   NaN     NaN
#
# [114203 rows x 17 columns]
